# %%
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../output/2013_maxout_tourney_score_predictions.csv')

print data.keys()

sns.regplot(data['wscore_mean'], data['wscore_truth'])
sns.regplot(data['lscore_mean'], data['lscore_truth'])

plt.figure()

sns.distplot(data['wscore_var'])
sns.distplot(data['lscore_var'])

print data[data['wscore_var'] > data['wscore_var'].max()-2]
print data[data['wscore_var'] < data['wscore_var'].min()+1]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-84a5bee026d7> in <module>()
# ----> 1 data = pd.read_csv('../output/2013_maxout_tourney_score_predictions.csv')
#       2
#       3 print data.keys()
#       4
#       5 sns.regplot(data['wscore_mean'], data['wscore_truth'])
#
# ...

# %%
data = pd.read_csv('../output/2014_maxout_tourney_predictions.csv')
sns.regplot(data['wscore_mean'], data['wscore_truth'])
sns.regplot(data['lscore_mean'], data['lscore_truth'])

plt.figure()

sns.distplot(data['wscore_var'])
sns.distplot(data['lscore_var'])

# %%
data = pd.read_csv('../output/2015_maxout_tourney_predictions.csv')
sns.regplot(data['wscore_mean'], data['wscore_truth'])
sns.regplot(data['lscore_mean'], data['lscore_truth'])

plt.figure()

sns.distplot(data['wscore_var'])
sns.distplot(data['lscore_var'])

# %%
data = pd.read_csv('../output/2016_maxout_tourney_predictions.csv')
sns.regplot(data['wscore_mean'], data['wscore_truth'])
sns.regplot(data['lscore_mean'], data['lscore_truth'])

plt.figure()

sns.distplot(data['wscore_var'])
sns.distplot(data['lscore_var'])
